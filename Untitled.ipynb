# %%
from langchain_ollama import ChatOllama

# %%
prompt = 'Hello . Do you know my name?'
llm = ChatOllama(model='llama3.2', temperature=0.0,  num_predict =10)
response = llm.invoke(prompt)
print(response.content)
# Out:
# I'm happy to chat with you, but I

# %%
prompt = 'My name is Ram Khandelwal'
llm = ChatOllama(model='llama3.2', temperature=0.0)
response = llm.invoke(prompt)
print(response.content)
# Out:
# Namaste Ram Khandelwal! It's nice to meet you. Is there something I can help you with or would you like to chat?

# %%
prompt = """
you are chatbot use this context for reference 
Context :
Human :Hello . Do you know my name?
System :I'm happy to chat with you, but I don't have any information about your name. I'm a large language model, I don't have the ability to store or recall personal information about individual users. Each time you interact with me, it's a new conversation and I don't retain any information from previous conversations. Would you like to introduce yourself?
Human : My name is Ram Khandelwal

And answer my question in single sentence 

Questiion : What is my name ?
"""
llm = ChatOllama(model='llama3.2', temperature=0.0)
response = llm.invoke(prompt)
print(response.content)
# Out:
# I don't have any information about your name, Ram Khandelwal, as our conversation just started and I don't retain any information from previous conversations.
