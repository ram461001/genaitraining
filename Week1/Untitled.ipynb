# %%
import time 
import asyncio
async def test():
    for i in range(6):
        asyncio.sleep(2)
        print( "test" , i)

async def run():
    for i in range(5):
        asyncio.sleep(1)
        print( "run" , i)

# %%
await test()
await run()
# Out:
# test 0
# test 1
# test 2
# test 3
# test 4
# test 5
# run 0
# run 1
# run 2
# run 3
# run 4
# /var/folders/sc/1vv0jvm14872pnrqv86vd88h0000gp/T/ipykernel_59508/728656615.py:5: RuntimeWarning: coroutine 'sleep' was never awaited
#   asyncio.sleep(2)
# ...
# /var/folders/sc/1vv0jvm14872pnrqv86vd88h0000gp/T/ipykernel_59508/728656615.py:10: RuntimeWarning: coroutine 'sleep' was never awaited
#   asyncio.sleep(1)
# ...
